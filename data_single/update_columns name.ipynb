# %%
import pandas as pd

# %%
for city in [2704302, 2927408, 2111300, 2211001,
            2800308, 2408102, 2304400, 2507507, 2611606]:
    
    df = pd.read_csv(f'dengue_{city}.csv', index_col = 'Unnamed: 0')
    
    df.columns = df.columns + '_' + str(city)
    
    df.to_csv(f'dengue_{city}.csv')
    
df.head()
# Out:
#             casos_2611606  casos_est_2611606  casos_est_min_2611606  \
# 2010-01-03              3                3.0                      3
# 2010-01-10              1                1.0                      1
# 2010-01-17              2                2.0                      2
# 2010-01-24              1                1.0                      1
# 2010-01-31              0                0.0                      0
#
#             casos_est_max_2611606  p_rt1_2611606  p_inc100k_2611606  \
# 2010-01-03                      3            0.0           0.181438
# 2010-01-10                      1            0.0           0.060479
# 2010-01-17                      2            0.0           0.120958
# 2010-01-24                      1            0.0           0.060479
# 2010-01-31                      0            0.0           0.000000
#
#             temp_min_2611606  temp_mean_2611606  temp_max_2611606  \
# 2010-01-03         23.566655          26.663263         29.759870
# ...
