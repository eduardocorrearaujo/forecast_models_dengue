# %%
from conformal_regressor import make_pred

# %%
city = 2304400
ini_date = None
end_train_date = '2021-12-26'
end_date = '2023-07-02'
predict_n = 4
look_back = 4
ratio = None

filename = f'../../data_cluster/dengue_{city}_cluster.csv'

# %%
# %%time
for city in [2704302, 2927408, 2111300, 2211001,
            2800308, 2408102, 2304400, 2507507, 2611606]:
    label = 'cluster'
    filename = f'../../data_cluster/dengue_{city}_cluster.csv'
    
    make_pred(city, ini_date, end_train_date, end_date, ratio, filename, label, doenca= 'dengue', predict_n = 4, look_back=4)
# Out:
# CPU times: user 58.7 s, sys: 316 ms, total: 59 s
# Wall time: 49.6 s
